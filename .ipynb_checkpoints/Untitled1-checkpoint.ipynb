# %%
import numpy as np
import math
import PIL
from matplotlib.pyplot import imshow

# %%
img = PIL.Image.open('lena.png', 'r')

# %%
img_arr = np.array(img)
img_arr1 = img_arr.copy()

# %%
def exchange(i, j):
    temp = i
    i = j
    j = temp
    
    return i, j

# %%
i = 2
j = 3
i, j = exchange(i,j)

# %%
print(i,j)
# Out:
# 3 2

# %%
# cipher_img = np.empty(img_arr.shape)
def scramble(img_arr):
    for i in range(1, img_arr.shape[0] - 1):
        for j in range(1, img_arr.shape[1] - 1):
            for k in range(3):
    #             print(i,j,k)
                img_arr[i-1, j-1, k], img_arr[i+1, j-1, k] = exchange(img_arr[i-1, j-1, k], img_arr[i+1, j-1, k])
                img_arr[i, j-1, k], img_arr[i, j+1, k] = exchange(img_arr[i, j-1, k], img_arr[i, j+1, k])
                img_arr[i-1, j+1, k], img_arr[i, j+1, k] = exchange(img_arr[i-1, j+1, k], img_arr[i, j+1, k])
                img_arr[i+1, j-1, k], img_arr[i+1, j+1, k] = exchange(img_arr[i+1, j-1, k], img_arr[i+1, j+1, k])
                img_arr[i-1, j, k], img_arr[i+1, j+1, k] = exchange(img_arr[i-1, j, k], img_arr[i+1, j+1, k])
                
    return img_arr

# %%
imshow(img_arr1)

# %%
imshow(img_arr)

# %%
imshow(img_arr1-img_arr)
